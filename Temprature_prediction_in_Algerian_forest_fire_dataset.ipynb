# %%
##Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Algerian_forest_fires_dataset.csv")

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df.describe()
# Out:
#         day month  year Temperature   RH   Ws Rain   FFMC  DMC   DC  ISI  BUI  \
# count   246   245   245         245  245  245   245   245  245  245  245  245
# unique   33     5     2          20   63   19    40   174  167  199  107  175
# top       1     7  2012          35   64   14     0  88.9  7.9    8  1.1    3
# freq      8    62   244          29   10   43   133     8    5    5    8    5
#
#         FWI Classes
# count   245       244
# unique  127         9
# top     0.4   fire
# freq     12       131

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.1+ KB

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %% [markdown]
# ##Data Preprocessing

# %%
df.isnull().sum()
# Out:
# day            1
# month          2
# year           2
# Temperature    2
#  RH            2
#  Ws            2
# Rain           2
# FFMC           2
# DMC            2
# DC             2
# ISI            2
# BUI            2
# FWI            2
# Classes        3
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122                            NaN   NaN   NaN         NaN  NaN  NaN   NaN
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 168                             14     7  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 123   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 168  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df.loc[:123,"region"]=0  ## Bejaia region
df.loc[123:,"region"]=1  ## Sidi Bel-abbes region

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    region
# 0    0.5   not fire        0.0
# ...

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    region
# 0  not fire        0.0
# 1  not fire        0.0
# 2  not fire        0.0
# 3  not fire        0.0
# 4  not fire        0.0

# %%
df["region"]=df["region"].astype(int) ##Changing region to int

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    region
# 0    0.5   not fire          0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  region       247 non-null    int32
# dtypes: int32(1), object(14)
# memory usage: 28.1+ KB

# %%
##Checking null values in dataset
df.isnull().sum()
# Out:
# day            1
# month          2
# year           2
# Temperature    2
#  RH            2
#  Ws            2
# Rain           2
# FFMC           2
# DMC            2
# DC             2
# ISI            2
# BUI            2
# FWI            2
# Classes        3
# region         0
# dtype: int64

# %%
##drop null values
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# region         0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [day, month, year, Temperature,  RH,  Ws, Rain , FFMC, DMC, DC, ISI, BUI, FWI, Classes  , region]
# Index: []

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    region
# 0    0.5   not fire          0
# ...

# %%
df.iloc[122]
# Out:
# day                    day
# month                month
# year                  year
# Temperature    Temperature
#  RH                     RH
#  Ws                     Ws
# Rain                 Rain
# FFMC                  FFMC
# DMC                    DMC
# DC                      DC
# ISI                    ISI
# BUI                    BUI
# FWI                    FWI
# Classes          Classes
# region                   1
# Name: 124, dtype: object

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 124  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    region
# 124  FWI  Classes         1

# %%
df.drop(index=124,inplace=True)

# %%
df.reset_index(inplace=True)   ##resetting indexes

# %%
df
# Out:
#      index day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  \
# 0        0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3
# 1        1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1
# 2        2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3
# 3        3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0
# 4        4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2
# ..     ...  ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...
# 238    242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5
# 239    243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1
# 240    244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4
# 241    245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7
# 242    246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2
#
#       BUI  FWI     Classes    region
# ...

# %%
df.columns
# Out:
# Index(['index', 'day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ',
#        'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'region'],
#       dtype='object')

# %%
df.columns=df.columns.str.strip()  ##removing spaces from dataset

# %%
df.columns
# Out:
# Index(['index', 'day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain',
#        'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        243 non-null    int64
#  1   day          243 non-null    object
#  2   month        243 non-null    object
#  3   year         243 non-null    object
#  4   Temperature  243 non-null    object
#  5   RH           243 non-null    object
#  6   Ws           243 non-null    object
#  7   Rain         243 non-null    object
#  8   FFMC         243 non-null    object
#  9   DMC          243 non-null    object
#  10  DC           243 non-null    object
#  11  ISI          243 non-null    object
#  12  BUI          243 non-null    object
#  13  FWI          243 non-null    object
#  14  Classes      243 non-null    object
#  15  region       243 non-null    int32
# dtypes: int32(1), int64(1), object(14)
# memory usage: 29.6+ KB

# %%
df.head()
# Out:
#    index day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0      0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4
# 1      1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9
# 2      2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3      3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7
# 4      4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9
#
#    FWI      Classes  region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3    0  not fire          0
# 4  0.5  not fire          0

# %% [markdown]
# #Converting some objects features into Integer

# %%
df[["day","month","year","Temperature","RH","Ws"]]=df[["day","month","year","Temperature","RH","Ws"]].astype(int)

# %%
df.head()
# Out:
#    index  day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  \
# 0      0    1      6  2012           29  57  18     0  65.7  3.4   7.6  1.3
# 1      1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6    1
# 2      2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3
# 3      3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9    0
# 4      4    5      6  2012           27  77  16     0  64.8    3  14.2  1.2
#
#    BUI  FWI      Classes  region
# 0  3.4  0.5  not fire          0
# 1  3.9  0.4  not fire          0
# 2  2.7  0.1  not fire          0
# 3  1.7    0  not fire          0
# 4  3.9  0.5  not fire          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        243 non-null    int64
#  1   day          243 non-null    int32
#  2   month        243 non-null    int32
#  3   year         243 non-null    int32
#  4   Temperature  243 non-null    int32
#  5   RH           243 non-null    int32
#  6   Ws           243 non-null    int32
#  7   Rain         243 non-null    object
#  8   FFMC         243 non-null    object
#  9   DMC          243 non-null    object
#  10  DC           243 non-null    object
#  11  ISI          243 non-null    object
#  12  BUI          243 non-null    object
#  13  FWI          243 non-null    object
#  14  Classes      243 non-null    object
#  15  region       243 non-null    int32
# dtypes: int32(7), int64(1), object(8)
# memory usage: 23.9+ KB

# %%
df.drop("index",axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  region       243 non-null    int32
# dtypes: int32(7), object(8)
# memory usage: 22.0+ KB

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'region'],
#       dtype='object')

# %% [markdown]
# #Converting some objects features into Integer

# %%
df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']]=df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  region       243 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 22.0+ KB

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %% [markdown]
# ##removing not useful columns day, month, and year

# %%
df.drop(["day","month","year"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df["Classes"]
# Out:
# 0       not fire
# 1       not fire
# 2       not fire
# 3       not fire
# 4       not fire
#            ...
# 238         fire
# 239     not fire
# 240     not fire
# 241     not fire
# 242    not fire
# Name: Classes, Length: 243, dtype: object

# %%
df["Classes"].unique()
# Out:
# array(['not fire   ', 'fire   ', 'fire', 'fire ', 'not fire', 'not fire ',
#        'not fire     ', 'not fire    '], dtype=object)

# %%
df["Classes"]=df["Classes"].str.rstrip()

# %%
df["Classes"].unique()
# Out:
# array(['not fire', 'fire'], dtype=object)

# %% [markdown]
# ##Performing OHE for classes feature

# %%
df["Classes"]=np.where(df["Classes"].str.contains("not fire"),0,1)

# %%
df["Classes"].unique()
# Out:
# array([0, 1])

# %%
df["Classes"].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df.sample(5)
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC   ISI   BUI   FWI  Classes  \
# 133           27  58  17   0.0  88.9  21.3  37.8   8.7  21.2  12.9        1
# 192           40  31  15   0.0  94.2  22.5  46.3  16.6  22.4  21.6        1
# 155           34  58  18   0.0  88.0  13.6  36.8   8.0  14.1   9.9        1
# 236           26  49   6   2.0  61.3  11.9  28.1   0.6  11.9   0.4        0
# 70            35  55  14   0.0  88.9  18.6  67.0   7.4  21.9  11.6        1
#
#      region
# 133       1
# 192       1
# 155       1
# 236       1
# 70        0

# %% [markdown]
# ##Performing EDA

# %%
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %%
df.columns
# Out:
# Index(['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI',
#        'FWI', 'Classes', 'region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  243 non-null    int32
#  1   RH           243 non-null    int32
#  2   Ws           243 non-null    int32
#  3   Rain         243 non-null    float64
#  4   FFMC         243 non-null    float64
#  5   DMC          243 non-null    float64
#  6   DC           243 non-null    float64
#  7   ISI          243 non-null    float64
#  8   BUI          243 non-null    float64
#  9   FWI          243 non-null    float64
#  10  Classes      243 non-null    int32
#  11  region       243 non-null    int32
# dtypes: float64(7), int32(5)
# memory usage: 18.2 KB

# %%
sns.set(style="whitegrid")

# %% [markdown]
# ##histogram

# %%
plt.figure(figsize=(12, 8))
for i, col in enumerate(df.columns):
    plt.subplot(3, 4, i+1)
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##boxplot

# %%
plt.figure(figsize=(12, 8))
for i, col in enumerate(df.columns):
    plt.subplot(3, 4, i+1)
    sns.boxplot(data=df, y=col)
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()

# %%
df.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %% [markdown]
# #correlation matrix

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title('Correlation Matrix of Continuous Variables')
plt.show()

# %% [markdown]
# ##pairplot representation

# %%
sns.pairplot(df, hue='Classes', palette='Set1')

# %%
# Countplot for fire vs. not fire
sns.countplot(x='Classes', data=df, palette='Set2')
plt.title('Fire vs. Not Fire')
plt.show()
# Out:
# C:\Users\kulde\AppData\Local\Temp\ipykernel_18672\572081584.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Classes', data=df, palette='Set2')

# %%
# Countplot for regions
sns.countplot(x='region', data=df, palette='Set1')
plt.title('Region Distribution')
plt.show()
# Out:
# C:\Users\kulde\AppData\Local\Temp\ipykernel_18672\441205937.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='region', data=df, palette='Set1')

# %%
##pie chart for fire and non fire
fire_counts = df['Classes'].value_counts()
sizes = [fire_counts[1], fire_counts[0]]
plt.pie(sizes, labels=['Fire', 'Not Fire'], autopct='%1.1f%%')
plt.title('Percentage of Fire vs. Not Fire')
plt.show()

# %% [markdown]
# #'Temperature Scatter Plot: Fire vs Not Fire'

# %%
sns.scatterplot(x=df.index, y='Temperature', hue='Classes', data=df, palette=['#ff6666', '#66b3ff'], alpha=0.7)
plt.title('Temperature Scatter Plot: Fire vs Not Fire')
plt.xlabel('Index')
plt.ylabel('Temperature (°C)')
plt.show()

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df_copy=df

# %%
# columns = df_copy[['Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI']]

# # Loop through each column and apply the IQR method
# for col in columns:
#     Q1 = df_copy[col].quantile(0.25)
#     Q3 = df_copy[col].quantile(0.75)
#     IQR = Q3 - Q1

#     # Define outlier bounds
#     lower_bound = Q1 - 1.5 * IQR
#     upper_bound = Q3 + 1.5 * IQR

#     # Filter out the outliers
#     df_copy= df_copy[(df_copy[col] >= lower_bound) & (df_copy[col] <= upper_bound)]

# %% [markdown]
# ##Splitting data into X and y

# %%
X=df_copy.iloc[:,1:]
y=df_copy[["Temperature"]]

# %%
X
# Out:
#      RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  region
# 0    57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5        0       0
# 1    61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4        0       0
# 2    82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1        0       0
# 3    89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0        0       0
# 4    77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5        0       0
# ..   ..  ..   ...   ...   ...   ...  ...   ...  ...      ...     ...
# 238  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1       1
# 239  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0       1
# 240  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0       1
# 241  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0       1
# 242  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0       1
#
# [243 rows x 11 columns]

# %%
y
# Out:
#      Temperature
# 0             29
# 1             29
# 2             26
# 3             25
# 4             27
# ..           ...
# 238           30
# 239           28
# 240           27
# 241           24
# 242           24
#
# [243 rows x 1 columns]

# %% [markdown]
# ##Performing sklearn Train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.80,random_state=42)

# %%
X_train.shape
# Out:
# (194, 11)

# %%
y_train.shape
# Out:
# (194, 1)

# %%
X_test.shape,y_test.shape
# Out:
# ((49, 11), (49, 1))

# %%
X_train.corr()
# Out:
#                RH        Ws      Rain      FFMC       DMC        DC       ISI  \
# RH       1.000000  0.211645  0.239441 -0.649239 -0.401836 -0.220945 -0.714640
# Ws       0.211645  1.000000  0.235922 -0.176596  0.004712  0.092866 -0.002300
# Rain     0.239441  0.235922  1.000000 -0.547864 -0.288538 -0.301110 -0.349903
# FFMC    -0.649239 -0.176596 -0.547864  1.000000  0.611978  0.519513  0.751819
# DMC     -0.401836  0.004712 -0.288538  0.611978  1.000000  0.876122  0.679049
# DC      -0.220945  0.092866 -0.301110  0.519513  0.876122  1.000000  0.512934
# ISI     -0.714640 -0.002300 -0.349903  0.751819  0.679049  0.512934  1.000000
# BUI     -0.346511  0.037465 -0.299179  0.598248  0.983891  0.946181  0.637669
# FWI     -0.600901  0.019499 -0.328108  0.707374  0.880473  0.748819  0.918762
# Classes -0.454926 -0.075322 -0.378585  0.786012  0.606775  0.538893  0.740072
# region  -0.408441 -0.202357 -0.057382  0.254770  0.188980 -0.083038  0.291889
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(X_train.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##checking Multicollinearity

# %%
def correlation(dataset, threshold):
    col_corr = []
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.append(colname)
    return col_corr

# %%
corr_columns=correlation(X_train,0.90)

# %%
corr_columns
# Out:
# ['BUI', 'BUI', 'FWI']

# %%
X_train.drop("BUI",inplace=True,axis=1)
X_train.drop("FWI",inplace=True,axis=1)
X_test.drop("BUI",inplace=True,axis=1)
X_test.drop("FWI",inplace=True,axis=1)

# %%
X_train.shape,X_test.shape
# Out:
# ((194, 9), (49, 9))

# %%
##Performing Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 0.21321832,  1.28577038, -0.09206896, ..., -0.79648833,
#         -1.14434427, -1.01036297],
#        [-1.65484925,  0.14504117, -0.38015572, ...,  1.88757476,
#          0.8738629 ,  0.98974332],
#        [-1.25454906, -0.99568804, -0.14008342, ..., -0.19488798,
#          0.8738629 ,  0.98974332],
#        ...,
#        [ 0.947102  ,  0.52528424,  3.0768854 , ..., -1.0972885 ,
#         -1.14434427, -1.01036297],
#        [-0.18708188,  0.14504117, -0.38015572, ...,  0.56868169,
#          0.8738629 ,  0.98974332],
#        [ 1.0138187 ,  2.04625653,  0.48410456, ..., -0.88904223,
#         -1.14434427, -1.01036297]])

# %%
X_test_scaled
# Out:
# array([[ 0.14650162, -0.2352019 , -0.38015572,  0.61070375, -0.07699537,
#          0.25303529,  0.17532762,  0.8738629 , -1.01036297],
#        [-0.52066537, -0.99568804, -0.38015572,  0.71720269, -0.40637763,
#         -0.41556406,  0.33729694,  0.8738629 , -1.01036297],
#        [-0.25379858,  0.90552731,  0.6761624 , -1.02228009, -0.91960114,
#         -0.85728135, -0.86590375, -1.14434427,  0.98974332],
#        [-0.25379858, -0.99568804, -0.2841268 ,  0.09950881,  0.26770699,
#          0.7389243 , -0.65765748, -1.14434427,  0.98974332],
#        [ 0.21321832, -0.61544497, -0.38015572,  0.51840466,  0.06088557,
#         -0.13447124, -0.10233408,  0.8738629 ,  0.98974332],
#        [ 0.14650162, -2.51666033,  0.1960178 , -0.30518719, -0.26849668,
#         -0.70870372, -0.88904223, -1.14434427,  0.98974332],
#        [ 0.8803853 ,  0.14504117, -0.38015572,  0.29120691, -0.82768051,
#         -0.54004803, -0.37999578,  0.8738629 ,  0.98974332],
# ...

# %% [markdown]
# ##BOX plot for X_train Before Scaling and X_train After Scaling

# %%
plt.subplots(figsize=(15, 5))
plt.subplot(1, 2, 1)
sns.boxplot(data=X_train)
plt.title('X_train Before Scaling')
plt.subplot(1, 2, 2)
sns.boxplot(data=X_train_scaled)
plt.title('X_train After Scaling')
# Out:
# Text(0.5, 1.0, 'X_train After Scaling')

# %% [markdown]
# ##Performing Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train_scaled,y_train)
y_pred=lr.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
print("Mean absolute error", mae)
# Out:
# Mean absolute error 2.181223685187666

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print("R2 Score", score)
# Out:
# R2 Score 0.4282103335799937

# %%
plt.scatter(y_test,y_pred)

# %% [markdown]
# ##Performing Lasso Regression

# %%
from sklearn.linear_model import Lasso
lasso=Lasso()
lasso.fit(X_train_scaled,y_train)
y_pred=lasso.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 2.11723454318823
# R2 Score 0.4672766492333088
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[110], line 8
#       6 print("Mean absolute error", mae)
#       7 print("R2 Score", score)
# ----> 8 rmse = np.sqrt(mse)
#       9 print("Root Mean Squared Error:", rmse)
#
# NameError: name 'mse' is not defined

# %%
plt.scatter(y_test,y_pred)

# %% [markdown]
# ##Performing LassoCV Regression

# %%
from sklearn.linear_model import LassoCV
lassocv=LassoCV(cv=5)
lassocv.fit(X_train_scaled,y_train)
y_pred=lassocv.predict(X_test_scaled)
# Out:
# C:\Users\kulde\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1656: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 2.130441874468293
# R2 Score 0.46334673220575107

# %%
plt.scatter(y_test,y_pred)

# %% [markdown]
# ##Performing Ridge Regression

# %%
from sklearn.linear_model import Ridge
ridge=Ridge()
ridge.fit(X_train_scaled,y_train)
y_pred=ridge.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 2.175630710226027
# R2 Score 0.4315103118223941

# %%
plt.scatter(y_test,y_pred)

# %% [markdown]
# ##Performing RidgeCV Regression

# %%
from sklearn.linear_model import RidgeCV
ridgecv=RidgeCV(cv=5)
ridgecv.fit(X_train_scaled,y_train)
y_pred=ridgecv.predict(X_test_scaled)

# %%
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 2.135782386015827
# R2 Score 0.45285479448663735

# %%
plt.scatter(y_test,y_pred)

# %% [markdown]
# ##Performing ElasticNet Regression

# %%
from sklearn.linear_model import ElasticNet

elastic=ElasticNet()
elastic.fit(X_train_scaled,y_train)
y_pred=elastic.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 2.121142294484653
# R2 Score 0.4540687233263526

# %%
plt.scatter(y_test,y_pred)

# %% [markdown]
# ##Performing ElasticNetCV Regression

# %%
from sklearn.linear_model import ElasticNetCV
elasticcv=ElasticNetCV(cv=5)
elasticcv.fit(X_train_scaled,y_train)
y_pred=elasticcv.predict(X_test_scaled)
# Out:
# C:\Users\kulde\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1656: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 2.11723454318823
# R2 Score 0.4672766492333088

# %%
plt.scatter(y_test,y_pred)
